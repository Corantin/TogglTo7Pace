# %% [markdown]
# This script is used to convert toggl time entries to 7pace
#
# # Requirements
# - Create the .env file starting from the .env.template file
# - Toggl entries should be the result of the work item copy button
# - Configurate the #Constants block

# %% [markdown]
# Set variables from environment variables

# %%
import os
import sys
from dotenv import load_dotenv

load_dotenv(override=True)

# Constants

TOGGL_API_KEY = os.getenv('TOGGL_API_KEY')
TOGGL_WORKSPACE_ID = os.getenv('TOGGL_WORKSPACE_ID')
TOGGL_PROJECT_ID = os.getenv('TOGGL_PROJECT_ID')
SEVENPACE_API_KEY = os.getenv('SEVENPACE_API_KEY')
SEVENPACE_API_VERSION = os.getenv('SEVENPACE_API_VERSION')
DEVOPS_PERSONAL_ACCESS_TOKEN = os.getenv('DEVOPS_PERSONAL_ACCESS_TOKEN')

# If True, will only consider work items that were updated in the last week (vs current week)
LAST_WEEK = eval(os.getenv('LAST_WEEK'))

# Will be considered a TFS work item (not Azure Devops) if the work item id is greater than this number
TFS_7PACE_WORK_ITEM_THRESHOLD_START = int(os.getenv('TFS_7PACE_WORK_ITEM_THRESHOLD_START'))

# %%
import requests

# HTTP GET request to Toggl API


def TogglHttpGet(url, params):
    response = requests.get(url, auth=(
        TOGGL_API_KEY, 'api_token'), params=params)
    return response.json()

# %%
# Load the start and end dates of the current day week
from datetime import datetime, timedelta
day = datetime.now().strftime('%d/%b/%Y')
dt = datetime.strptime(day, '%d/%b/%Y')
start_day = (dt - timedelta(days=dt.weekday()))
if LAST_WEEK:
    start_day = start_day - timedelta(days=7)
end_day = start_day + timedelta(days=6)
print("Start: " + start_day.strftime('%Y-%m-%d'))
print("End: " + end_day.strftime('%Y-%m-%d'))
# Out:
# Start: 2023-12-04
# End: 2023-12-10

# %%
import json

# Load toggl time entries for the specified project
TogglFetchEntriesUrl = 'https://api.track.toggl.com/api/v9/me/time_entries'
TimeEntries = TogglHttpGet(TogglFetchEntriesUrl, {
    'start_date': start_day.strftime('%Y-%m-%d'),
    'end_date': end_day.strftime('%Y-%m-%d')
})
# Filter time entries for the specified project
TimeEntries = [entry for entry in TimeEntries if entry['pid']
               == int(TOGGL_PROJECT_ID)]
print(json.dumps(TimeEntries, indent=4))
# Out:
# [
#     {
#         "id": 3241189799,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-08T23:07:21+00:00",
#         "stop": "2023-12-08T23:30:51Z",
#         "duration": 1410,
#         "description": "Feature 80836: Login refactoring",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-08T23:30:51+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3241131711,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-08T21:33:48+00:00",
#         "stop": "2023-12-08T23:07:21Z",
#         "duration": 5613,
#         "description": "SwatTask 3427611: [Syracuse City School District] Web app Role gives warning \" failed to start agent\" if add failover server",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-08T23:30:43+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3240880525,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-08T17:16:13+00:00",
#         "stop": "2023-12-08T21:33:48Z",
#         "duration": 15455,
#         "description": "Feature 80836: Login refactoring",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-08T21:55:45+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3240794879,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-08T16:37:36+00:00",
#         "stop": "2023-12-08T17:38:00Z",
#         "duration": 3624,
#         "description": "Bug 146087: Privileges - With some privileges disabled, you can still see the task/subtask and interact with entities.",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-08T17:38:01+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3240737356,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-08T15:35:09+00:00",
#         "stop": "2023-12-08T16:15:19Z",
#         "duration": 2410,
#         "description": "User Story 3676090: Replace Mobius by NYPD logo",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-08T16:32:28+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3240663701,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-08T15:00:12+00:00",
#         "stop": "2023-12-08T15:35:00Z",
#         "duration": 2088,
#         "description": "Daily",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-08T15:54:06+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3239747671,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-07T22:47:15+00:00",
#         "stop": "2023-12-07T23:52:31Z",
#         "duration": 3916,
#         "description": "User Story 3676090: Replace Mobius by NYPD logo",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-08T15:05:12+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3239747138,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-07T21:29:11+00:00",
#         "stop": "2023-12-07T22:47:05Z",
#         "duration": 4674,
#         "description": "Technical Debt 144333: Create the default task user option",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-07T22:47:06+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3239666195,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-07T21:23:34+00:00",
#         "stop": "2023-12-07T21:29:11Z",
#         "duration": 337,
#         "description": "Technical Debt 145882: WebApp - Access Rules - Hide sub task behind a feature flag.",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-07T22:46:35+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3239645635,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-07T21:04:28+00:00",
#         "stop": "2023-12-07T21:23:32Z",
#         "duration": 1144,
#         "description": "User Story 145268: Support privacy protected streams in the webapp",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-07T21:23:33+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3239615399,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-07T20:38:22+00:00",
#         "stop": "2023-12-07T21:04:25Z",
#         "duration": 1563,
#         "description": "PR 145947: NavWithProfile - Add Setting and Send Feedback to nav bar",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-07T21:04:26+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3239598260,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-07T20:24:15+00:00",
#         "stop": "2023-12-07T20:38:20Z",
#         "duration": 845,
#         "description": "Bug 144728: Access Control - Credentials - Save always fail on a certain credential",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-07T20:38:20+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3239434960,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-07T17:45:41+00:00",
#         "stop": "2023-12-07T20:24:13Z",
#         "duration": 9512,
#         "description": "User Story 3676090: Replace Mobius by NYPD logo",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-07T20:24:13+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3239149188,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-07T15:21:51+00:00",
#         "stop": "2023-12-07T16:35:28Z",
#         "duration": 4417,
#         "description": "Bug 145398: WebApp - Refreshing the page takes a long time and then logs you out",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-07T16:35:40+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3238031184,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-06T22:29:15+00:00",
#         "stop": "2023-12-07T00:29:15Z",
#         "duration": 7200,
#         "description": "User Story 3676090: Replace Mobius by NYPD logo",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-07T00:29:16+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3238028214,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-06T22:26:23+00:00",
#         "stop": "2023-12-06T22:29:08Z",
#         "duration": 165,
#         "description": "Bug 145398: WebApp - Refreshing the page takes a long time and then logs you out",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-06T22:29:09+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3238027558,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-06T21:26:55+00:00",
#         "stop": "2023-12-06T22:26:16Z",
#         "duration": 3561,
#         "description": "Training: Starbuck Business Accumen",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-06T22:26:17+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3237723610,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-06T18:07:25+00:00",
#         "stop": "2023-12-06T21:26:55Z",
#         "duration": 11970,
#         "description": "Bug 145398: WebApp - Refreshing the page takes a long time and then logs you out",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-06T22:25:47+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3237592597,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-06T16:30:23+00:00",
#         "stop": "2023-12-06T17:35:45Z",
#         "duration": 3922,
#         "description": "User Story 3676090: Replace Mobius by NYPD logo",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-06T18:22:28+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3237381620,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-06T15:00:53+00:00",
#         "stop": "2023-12-06T15:25:11Z",
#         "duration": 1458,
#         "description": "Daily",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-06T15:32:21+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3235754548,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-05T16:15:02+00:00",
#         "stop": "2023-12-05T23:26:58Z",
#         "duration": 25916,
#         "description": "Feature 80836: Login refactoring",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-05T23:26:59+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3235670427,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-05T15:15:53+00:00",
#         "stop": "2023-12-05T16:14:56Z",
#         "duration": 3543,
#         "description": "EPM Feature 3674768: NYPD - Remove Genetec Logo",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-05T16:14:58+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3235605034,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-05T15:02:33+00:00",
#         "stop": "2023-12-05T15:15:53Z",
#         "duration": 800,
#         "description": "Daily",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-05T15:33:42+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3234471895,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-04T22:00:21+00:00",
#         "stop": "2023-12-04T23:17:27Z",
#         "duration": 4626,
#         "description": "Technical Debt 144908: WebApp - Add eslint rule for focus tests .only",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-04T23:17:28+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3234280960,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-04T20:33:19+00:00",
#         "stop": "2023-12-04T22:00:28Z",
#         "duration": 5229,
#         "description": "Feature 118384: Horizon: Automatically login",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-04T23:17:05+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3234146150,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-04T18:45:47+00:00",
#         "stop": "2023-12-04T20:32:49Z",
#         "duration": 6422,
#         "description": "Carrier path",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-04T20:32:50+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3233833182,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-04T15:30:09+00:00",
#         "stop": "2023-12-04T18:45:43Z",
#         "duration": 11734,
#         "description": "Technical Debt 144908: WebApp - Add eslint rule for focus tests .only",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-04T18:58:03+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     },
#     {
#         "id": 3233703048,
#         "workspace_id": 3602019,
#         "project_id": 190545217,
#         "task_id": null,
#         "billable": false,
#         "start": "2023-12-04T15:00:44+00:00",
#         "stop": "2023-12-04T15:16:28Z",
#         "duration": 944,
#         "description": "Daily",
#         "tags": [],
#         "tag_ids": [],
#         "duronly": true,
#         "at": "2023-12-04T15:16:29+00:00",
#         "server_deleted_at": null,
#         "user_id": 5025026,
#         "uid": 5025026,
#         "wid": 3602019,
#         "pid": 190545217
#     }
# ]

# %%
# Clear 7pace time entries for this week
import requests

url = f"https://geneteccentral.timehub.7pace.com/api/rest/workLogs/?api-version={SEVENPACE_API_VERSION}"
headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {SEVENPACE_API_KEY}'
}
response = requests.request("GET", url, headers=headers)
currentWeekWorklogs = []
for worklog in response.json()['data']:
  if worklog['timestamp'] >= start_day.strftime('%Y-%m-%d') and worklog['timestamp'] <= end_day.strftime('%Y-%m-%d'):
    currentWeekWorklogs.append(worklog)

if (len(currentWeekWorklogs) == 0):
  print("No entries already there in 7pace for this week")
else:
  print(json.dumps(
      list(map(lambda x: x['comment'], currentWeekWorklogs)), indent=2))

  inputResp = input(
      f"Deleting {str(len(currentWeekWorklogs))} entries. Continue ? (y/n)")
  if inputResp.lower() == 'n':
      exit

  error = False

  for worklog in currentWeekWorklogs:
    url = f"https://geneteccentral.timehub.7pace.com/api/rest/workLogs/{worklog['id']}?api-version={SEVENPACE_API_VERSION}"
    response = requests.request("DELETE", url, headers=headers)
  if not (response.status_code == 204 or response.status_code == 200):
    print("Error deleting worklog " + worklog['id'])
    print(response.text)
    error = True

  if not error:
    print(f"{str(len(currentWeekWorklogs))} worklogs deleted successfully")
# Out:
# [
#   "Feature 80836: Login refactoring",
#   "Feature 80836: Login refactoring",
#   "Bug 146087: Privileges - With some privileges disabled, you can still see the task/subtask and interact with entities.",
#   "Daily",
#   "Technical Debt 144333: Create the default task user option",
#   "Technical Debt 145882: WebApp - Access Rules - Hide sub task behind a feature flag.",
#   "User Story 145268: Support privacy protected streams in the webapp",
#   "PR 145947: NavWithProfile - Add Setting and Send Feedback to nav bar",
#   "Bug 144728: Access Control - Credentials - Save always fail on a certain credential",
#   "Bug 145398: WebApp - Refreshing the page takes a long time and then logs you out",
#   "Bug 145398: WebApp - Refreshing the page takes a long time and then logs you out",
#   "Training: Starbuck Business Accumen",
#   "Bug 145398: WebApp - Refreshing the page takes a long time and then logs you out",
#   "Daily",
#   "Feature 80836: Login refactoring",
#   "Daily",
#   "Technical Debt 144908: WebApp - Add eslint rule for focus tests .only",
#   "Feature 118384: Horizon: Automatically login",
#   "Carrier path",
#   "Technical Debt 144908: WebApp - Add eslint rule for focus tests .only",
#   "Daily"
# ]
# 21 worklogs deleted successfully

# %%
# Fetch 7pace user id
import requests

url = f"https://geneteccentral.timehub.7pace.com/api/rest/me?api-version={SEVENPACE_API_VERSION}"

payload = {}
headers = {
    'Authorization': 'Bearer ' + SEVENPACE_API_KEY
}
response = requests.request("GET", url, headers=headers, data=payload)
if not response.ok:
    print("Error fetching user id", response.text)
else:
  USER_ID = response.json()['data']['user']['id']
  print("USER_ID=" + USER_ID)
# Out:
# USER_ID=c4da23b7-8578-4f8b-994a-a1953d6b5f6a

# %%
# Fetch 7pace activities
import requests
import json
url = f"https://geneteccentral.timehub.7pace.com/api/rest/activityTypes?api-version={SEVENPACE_API_VERSION}"
headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {SEVENPACE_API_KEY}'
}
resp = requests.request("GET", url, headers=headers, data=payload)

# Retun a name/id map of activities
activities = {}
for activity in resp.json()['data']['activityTypes']:
  activities[activity['id']] = activity['name']
print(json.dumps(activities, indent=2))
# Out:
# {
#   "00000000-0000-0000-0000-000000000000": "[Not Set]",
#   "140dc2a9-03a0-4431-9f6b-0120f2c1b82f": "Bug Fixing",
#   "baebe11d-75e5-4bed-8644-d0ce8731a1b4": "Business development",
#   "cd0690af-8e15-4616-a9e3-f3bcfa0f3d5f": "Certification",
#   "d0ae0b59-b071-409b-80f9-c9c2626e08a1": "Customer issues",
#   "6a79b89e-4c6d-4866-b07b-428b65f1b1d5": "Customer Support and Services",
#   "430a57f9-9da2-41e9-97e8-34abdf3e70b2": "Development Infrastructure",
#   "9cd0cb39-180d-4b19-9265-83f9753ff76c": "Feature Development",
#   "191afffa-22b6-42fc-b93d-36426ae39a6c": "Initial Onboarding",
#   "ebccdf5e-93ce-4c94-8c31-c4d57712a28b": "People Centric Activities",
#   "2a032e88-7d97-44d3-b28e-ce89b4277017": "Professional Development",
#   "ccdf4989-6e17-450c-8c5b-9cfd8496de34": "Regression",
#   "bc23a96d-f6c5-44fe-be60-337af432d71b": "Technical Planning",
#   "4203e589-2db3-4726-8cb5-f28632ae0838": "Work Absence"
# }

# %%
# Convert Toggl time entries to 7pace format
from datetime import datetime, timezone, timedelta
import re

SevenPaceTimeEntries = []
for entry in TimeEntries:
    start = entry['start']
    duration = entry['duration']
    if(duration < 0):
      print("Ignoring entry with negative duration (pending timer)")
      continue
    notes = entry['description']
    workItemId = None
    numbers = re.findall(r'\d+:?', notes)
    if numbers:
        workItemId = int(numbers[0].rstrip(':'))

    # Default for Internal Operations
    activityTypeId = "ebccdf5e-93ce-4c94-8c31-c4d57712a28b"
    if ('technical debt' in notes.lower() or 'bug' in notes.lower()):
      activityTypeId = "140dc2a9-03a0-4431-9f6b-0120f2c1b82f"  # Bug
    elif ('feature' in notes.lower() or 'user story' in notes.lower() or 'pr' in notes.lower()):
      activityTypeId = "9cd0cb39-180d-4b19-9265-83f9753ff76c"  # Feature
    elif ('swattask' in notes.lower() or 'swat' in notes.lower()):
      activityTypeId = "d0ae0b59-b071-409b-80f9-c9c2626e08a1"  # Customer issues
    elif ('professional development' in notes.lower() or 'formation' in notes.lower()):
      activityTypeId = "2a032e88-7d97-44d3-b28e-ce89b4277017"  # Professional development

    SevenPaceTimeEntries.append({
        'timeStamp': start,
        'length': duration,
        'lengthFriendly': "{:0>8}".format(str(timedelta(seconds=duration))),
        'comment': notes,
        "workItemId": workItemId,
        'userId': USER_ID,
        'activityTypeId': activityTypeId,
        "activityFriendly": activities[activityTypeId]
    })

print(json.dumps(SevenPaceTimeEntries, indent=2))
# Out:
# [
#   {
#     "timeStamp": "2023-12-08T23:07:21+00:00",
#     "length": 1410,
#     "lengthFriendly": "00:23:30",
#     "comment": "Feature 80836: Login refactoring",
#     "workItemId": 80836,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "9cd0cb39-180d-4b19-9265-83f9753ff76c",
#     "activityFriendly": "Feature Development"
#   },
#   {
#     "timeStamp": "2023-12-08T21:33:48+00:00",
#     "length": 5613,
#     "lengthFriendly": "01:33:33",
#     "comment": "SwatTask 3427611: [Syracuse City School District] Web app Role gives warning \" failed to start agent\" if add failover server",
#     "workItemId": 3427611,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "d0ae0b59-b071-409b-80f9-c9c2626e08a1",
#     "activityFriendly": "Customer issues"
#   },
#   {
#     "timeStamp": "2023-12-08T17:16:13+00:00",
#     "length": 15455,
#     "lengthFriendly": "04:17:35",
#     "comment": "Feature 80836: Login refactoring",
#     "workItemId": 80836,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "9cd0cb39-180d-4b19-9265-83f9753ff76c",
#     "activityFriendly": "Feature Development"
#   },
#   {
#     "timeStamp": "2023-12-08T16:37:36+00:00",
#     "length": 3624,
#     "lengthFriendly": "01:00:24",
#     "comment": "Bug 146087: Privileges - With some privileges disabled, you can still see the task/subtask and interact with entities.",
#     "workItemId": 146087,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f",
#     "activityFriendly": "Bug Fixing"
#   },
#   {
#     "timeStamp": "2023-12-08T15:35:09+00:00",
#     "length": 2410,
#     "lengthFriendly": "00:40:10",
#     "comment": "User Story 3676090: Replace Mobius by NYPD logo",
#     "workItemId": 3676090,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "9cd0cb39-180d-4b19-9265-83f9753ff76c",
#     "activityFriendly": "Feature Development"
#   },
#   {
#     "timeStamp": "2023-12-08T15:00:12+00:00",
#     "length": 2088,
#     "lengthFriendly": "00:34:48",
#     "comment": "Daily",
#     "workItemId": null,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "ebccdf5e-93ce-4c94-8c31-c4d57712a28b",
#     "activityFriendly": "People Centric Activities"
#   },
#   {
#     "timeStamp": "2023-12-07T22:47:15+00:00",
#     "length": 3916,
#     "lengthFriendly": "01:05:16",
#     "comment": "User Story 3676090: Replace Mobius by NYPD logo",
#     "workItemId": 3676090,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "9cd0cb39-180d-4b19-9265-83f9753ff76c",
#     "activityFriendly": "Feature Development"
#   },
#   {
#     "timeStamp": "2023-12-07T21:29:11+00:00",
#     "length": 4674,
#     "lengthFriendly": "01:17:54",
#     "comment": "Technical Debt 144333: Create the default task user option",
#     "workItemId": 144333,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f",
#     "activityFriendly": "Bug Fixing"
#   },
#   {
#     "timeStamp": "2023-12-07T21:23:34+00:00",
#     "length": 337,
#     "lengthFriendly": "00:05:37",
#     "comment": "Technical Debt 145882: WebApp - Access Rules - Hide sub task behind a feature flag.",
#     "workItemId": 145882,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f",
#     "activityFriendly": "Bug Fixing"
#   },
#   {
#     "timeStamp": "2023-12-07T21:04:28+00:00",
#     "length": 1144,
#     "lengthFriendly": "00:19:04",
#     "comment": "User Story 145268: Support privacy protected streams in the webapp",
#     "workItemId": 145268,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "9cd0cb39-180d-4b19-9265-83f9753ff76c",
#     "activityFriendly": "Feature Development"
#   },
#   {
#     "timeStamp": "2023-12-07T20:38:22+00:00",
#     "length": 1563,
#     "lengthFriendly": "00:26:03",
#     "comment": "PR 145947: NavWithProfile - Add Setting and Send Feedback to nav bar",
#     "workItemId": 145947,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "9cd0cb39-180d-4b19-9265-83f9753ff76c",
#     "activityFriendly": "Feature Development"
#   },
#   {
#     "timeStamp": "2023-12-07T20:24:15+00:00",
#     "length": 845,
#     "lengthFriendly": "00:14:05",
#     "comment": "Bug 144728: Access Control - Credentials - Save always fail on a certain credential",
#     "workItemId": 144728,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f",
#     "activityFriendly": "Bug Fixing"
#   },
#   {
#     "timeStamp": "2023-12-07T17:45:41+00:00",
#     "length": 9512,
#     "lengthFriendly": "02:38:32",
#     "comment": "User Story 3676090: Replace Mobius by NYPD logo",
#     "workItemId": 3676090,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "9cd0cb39-180d-4b19-9265-83f9753ff76c",
#     "activityFriendly": "Feature Development"
#   },
#   {
#     "timeStamp": "2023-12-07T15:21:51+00:00",
#     "length": 4417,
#     "lengthFriendly": "01:13:37",
#     "comment": "Bug 145398: WebApp - Refreshing the page takes a long time and then logs you out",
#     "workItemId": 145398,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f",
#     "activityFriendly": "Bug Fixing"
#   },
#   {
#     "timeStamp": "2023-12-06T22:29:15+00:00",
#     "length": 7200,
#     "lengthFriendly": "02:00:00",
#     "comment": "User Story 3676090: Replace Mobius by NYPD logo",
#     "workItemId": 3676090,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "9cd0cb39-180d-4b19-9265-83f9753ff76c",
#     "activityFriendly": "Feature Development"
#   },
#   {
#     "timeStamp": "2023-12-06T22:26:23+00:00",
#     "length": 165,
#     "lengthFriendly": "00:02:45",
#     "comment": "Bug 145398: WebApp - Refreshing the page takes a long time and then logs you out",
#     "workItemId": 145398,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f",
#     "activityFriendly": "Bug Fixing"
#   },
#   {
#     "timeStamp": "2023-12-06T21:26:55+00:00",
#     "length": 3561,
#     "lengthFriendly": "00:59:21",
#     "comment": "Training: Starbuck Business Accumen",
#     "workItemId": null,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "ebccdf5e-93ce-4c94-8c31-c4d57712a28b",
#     "activityFriendly": "People Centric Activities"
#   },
#   {
#     "timeStamp": "2023-12-06T18:07:25+00:00",
#     "length": 11970,
#     "lengthFriendly": "03:19:30",
#     "comment": "Bug 145398: WebApp - Refreshing the page takes a long time and then logs you out",
#     "workItemId": 145398,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f",
#     "activityFriendly": "Bug Fixing"
#   },
#   {
#     "timeStamp": "2023-12-06T16:30:23+00:00",
#     "length": 3922,
#     "lengthFriendly": "01:05:22",
#     "comment": "User Story 3676090: Replace Mobius by NYPD logo",
#     "workItemId": 3676090,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "9cd0cb39-180d-4b19-9265-83f9753ff76c",
#     "activityFriendly": "Feature Development"
#   },
#   {
#     "timeStamp": "2023-12-06T15:00:53+00:00",
#     "length": 1458,
#     "lengthFriendly": "00:24:18",
#     "comment": "Daily",
#     "workItemId": null,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "ebccdf5e-93ce-4c94-8c31-c4d57712a28b",
#     "activityFriendly": "People Centric Activities"
#   },
#   {
#     "timeStamp": "2023-12-05T16:15:02+00:00",
#     "length": 25916,
#     "lengthFriendly": "07:11:56",
#     "comment": "Feature 80836: Login refactoring",
#     "workItemId": 80836,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "9cd0cb39-180d-4b19-9265-83f9753ff76c",
#     "activityFriendly": "Feature Development"
#   },
#   {
#     "timeStamp": "2023-12-05T15:15:53+00:00",
#     "length": 3543,
#     "lengthFriendly": "00:59:03",
#     "comment": "EPM Feature 3674768: NYPD - Remove Genetec Logo",
#     "workItemId": 3674768,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "9cd0cb39-180d-4b19-9265-83f9753ff76c",
#     "activityFriendly": "Feature Development"
#   },
#   {
#     "timeStamp": "2023-12-05T15:02:33+00:00",
#     "length": 800,
#     "lengthFriendly": "00:13:20",
#     "comment": "Daily",
#     "workItemId": null,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "ebccdf5e-93ce-4c94-8c31-c4d57712a28b",
#     "activityFriendly": "People Centric Activities"
#   },
#   {
#     "timeStamp": "2023-12-04T22:00:21+00:00",
#     "length": 4626,
#     "lengthFriendly": "01:17:06",
#     "comment": "Technical Debt 144908: WebApp - Add eslint rule for focus tests .only",
#     "workItemId": 144908,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f",
#     "activityFriendly": "Bug Fixing"
#   },
#   {
#     "timeStamp": "2023-12-04T20:33:19+00:00",
#     "length": 5229,
#     "lengthFriendly": "01:27:09",
#     "comment": "Feature 118384: Horizon: Automatically login",
#     "workItemId": 118384,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "9cd0cb39-180d-4b19-9265-83f9753ff76c",
#     "activityFriendly": "Feature Development"
#   },
#   {
#     "timeStamp": "2023-12-04T18:45:47+00:00",
#     "length": 6422,
#     "lengthFriendly": "01:47:02",
#     "comment": "Carrier path",
#     "workItemId": null,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "ebccdf5e-93ce-4c94-8c31-c4d57712a28b",
#     "activityFriendly": "People Centric Activities"
#   },
#   {
#     "timeStamp": "2023-12-04T15:30:09+00:00",
#     "length": 11734,
#     "lengthFriendly": "03:15:34",
#     "comment": "Technical Debt 144908: WebApp - Add eslint rule for focus tests .only",
#     "workItemId": 144908,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f",
#     "activityFriendly": "Bug Fixing"
#   },
#   {
#     "timeStamp": "2023-12-04T15:00:44+00:00",
#     "length": 944,
#     "lengthFriendly": "00:15:44",
#     "comment": "Daily",
#     "workItemId": null,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "ebccdf5e-93ce-4c94-8c31-c4d57712a28b",
#     "activityFriendly": "People Centric Activities"
#   }
# ]

# %%
# Publish worklogs to 7pace

import requests
import json


url = f"https://geneteccentral.timehub.7pace.com/api/rest/workLogs?api-version={SEVENPACE_API_VERSION}"
error = False
tfsEntries = []
devopsEntries = []
for entry in SevenPaceTimeEntries:
  if entry['workItemId'] != None and int(entry['workItemId']) > TFS_7PACE_WORK_ITEM_THRESHOLD_START:
    tfsEntries.append(entry)
  else:
    devopsEntries.append(entry)

    
inputResp = input(f"{str(len(devopsEntries))} entries to add. Continue ? (y/n)")
if inputResp.lower() == 'n':
  exit

for entry in devopsEntries:
  payload = json.dumps(entry)
  headers = {
      'Content-Type': 'application/json',
      'Authorization': f'Bearer {SEVENPACE_API_KEY}'
  }

  response = requests.request("POST", url, headers=headers, data=payload)
  print(json.dumps(response.json(), indent=2))
  if (response.status_code != 200):
    error = True

if (not error):
  print("Succeeded")
# Out:
# {
#   "data": {
#     "timestamp": "2023-12-08T23:07:21Z",
#     "length": 1410,
#     "billableLength": null,
#     "workItemId": 80836,
#     "comment": "Feature 80836: Login refactoring",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:35:52.0292991",
#     "editedTimestamp": "2023-12-12T15:35:52.0292991",
#     "activityType": {
#       "color": "46aee8",
#       "name": "Feature Development",
#       "id": "9cd0cb39-180d-4b19-9265-83f9753ff76c"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "b270afb4-dd74-4461-804c-598b46b2efee"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-08T17:16:13Z",
#     "length": 15455,
#     "billableLength": null,
#     "workItemId": 80836,
#     "comment": "Feature 80836: Login refactoring",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:35:52.7359682",
#     "editedTimestamp": "2023-12-12T15:35:52.7359682",
#     "activityType": {
#       "color": "46aee8",
#       "name": "Feature Development",
#       "id": "9cd0cb39-180d-4b19-9265-83f9753ff76c"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "e06446db-a569-4a3a-b86a-1843d6b16ffd"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-08T16:37:36Z",
#     "length": 3624,
#     "billableLength": null,
#     "workItemId": 146087,
#     "comment": "Bug 146087: Privileges - With some privileges disabled, you can still see the task/subtask and interact with entities.",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:35:53.181021",
#     "editedTimestamp": "2023-12-12T15:35:53.181021",
#     "activityType": {
#       "color": "cc293d",
#       "name": "Bug Fixing",
#       "id": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "ee037ac0-c45f-49d4-9c51-41e4474231a4"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-08T15:00:12Z",
#     "length": 2088,
#     "billableLength": null,
#     "workItemId": null,
#     "comment": "Daily",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:35:53.7170573",
#     "editedTimestamp": "2023-12-12T15:35:53.7170573",
#     "activityType": {
#       "color": "ff6600",
#       "name": "People Centric Activities",
#       "id": "ebccdf5e-93ce-4c94-8c31-c4d57712a28b"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "aae7b84e-e85a-44f4-aebb-b217d976ce81"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-07T21:29:11Z",
#     "length": 4674,
#     "billableLength": null,
#     "workItemId": 144333,
#     "comment": "Technical Debt 144333: Create the default task user option",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:35:54.0996899",
#     "editedTimestamp": "2023-12-12T15:35:54.0996899",
#     "activityType": {
#       "color": "cc293d",
#       "name": "Bug Fixing",
#       "id": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "9d124566-1d10-4b34-a276-4741b6847173"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-07T21:23:34Z",
#     "length": 337,
#     "billableLength": null,
#     "workItemId": 145882,
#     "comment": "Technical Debt 145882: WebApp - Access Rules - Hide sub task behind a feature flag.",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:35:54.7031933",
#     "editedTimestamp": "2023-12-12T15:35:54.7031933",
#     "activityType": {
#       "color": "cc293d",
#       "name": "Bug Fixing",
#       "id": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "af6ac8da-600d-4542-832b-f6360d30934f"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-07T21:04:28Z",
#     "length": 1144,
#     "billableLength": null,
#     "workItemId": 145268,
#     "comment": "User Story 145268: Support privacy protected streams in the webapp",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:35:55.5575248",
#     "editedTimestamp": "2023-12-12T15:35:55.5575248",
#     "activityType": {
#       "color": "46aee8",
#       "name": "Feature Development",
#       "id": "9cd0cb39-180d-4b19-9265-83f9753ff76c"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "a56a9c2d-51d2-438b-bbc5-a4eb0c153add"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-07T20:38:22Z",
#     "length": 1563,
#     "billableLength": null,
#     "workItemId": 145947,
#     "comment": "PR 145947: NavWithProfile - Add Setting and Send Feedback to nav bar",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:35:56.2441498",
#     "editedTimestamp": "2023-12-12T15:35:56.2441498",
#     "activityType": {
#       "color": "46aee8",
#       "name": "Feature Development",
#       "id": "9cd0cb39-180d-4b19-9265-83f9753ff76c"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "8323140d-fa32-4a40-a137-72223830a72b"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-07T20:24:15Z",
#     "length": 845,
#     "billableLength": null,
#     "workItemId": 144728,
#     "comment": "Bug 144728: Access Control - Credentials - Save always fail on a certain credential",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:35:57.0450171",
#     "editedTimestamp": "2023-12-12T15:35:57.0450171",
#     "activityType": {
#       "color": "cc293d",
#       "name": "Bug Fixing",
#       "id": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "9deb5952-5096-472a-8d17-cf9b3df5b106"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-07T15:21:51Z",
#     "length": 4417,
#     "billableLength": null,
#     "workItemId": 145398,
#     "comment": "Bug 145398: WebApp - Refreshing the page takes a long time and then logs you out",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:35:57.6081957",
#     "editedTimestamp": "2023-12-12T15:35:57.6081957",
#     "activityType": {
#       "color": "cc293d",
#       "name": "Bug Fixing",
#       "id": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "0ed234e4-3cee-4bfe-98b7-49dde3e4ae48"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-06T22:26:23Z",
#     "length": 165,
#     "billableLength": null,
#     "workItemId": 145398,
#     "comment": "Bug 145398: WebApp - Refreshing the page takes a long time and then logs you out",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:35:58.2672105",
#     "editedTimestamp": "2023-12-12T15:35:58.2672105",
#     "activityType": {
#       "color": "cc293d",
#       "name": "Bug Fixing",
#       "id": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "f9a87e68-d9c7-4c94-93ce-37dc3918d388"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-06T21:26:55Z",
#     "length": 3561,
#     "billableLength": null,
#     "workItemId": null,
#     "comment": "Training: Starbuck Business Accumen",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:35:58.8845837",
#     "editedTimestamp": "2023-12-12T15:35:58.8845837",
#     "activityType": {
#       "color": "ff6600",
#       "name": "People Centric Activities",
#       "id": "ebccdf5e-93ce-4c94-8c31-c4d57712a28b"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "c735447e-98c1-4982-8942-23f0e5486c1f"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-06T18:07:25Z",
#     "length": 11970,
#     "billableLength": null,
#     "workItemId": 145398,
#     "comment": "Bug 145398: WebApp - Refreshing the page takes a long time and then logs you out",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:35:59.3478469",
#     "editedTimestamp": "2023-12-12T15:35:59.3478469",
#     "activityType": {
#       "color": "cc293d",
#       "name": "Bug Fixing",
#       "id": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "fe8bde0c-094d-4aa0-bcce-ce7f47f7a638"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-06T15:00:53Z",
#     "length": 1458,
#     "billableLength": null,
#     "workItemId": null,
#     "comment": "Daily",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:35:59.8577643",
#     "editedTimestamp": "2023-12-12T15:35:59.8577643",
#     "activityType": {
#       "color": "ff6600",
#       "name": "People Centric Activities",
#       "id": "ebccdf5e-93ce-4c94-8c31-c4d57712a28b"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "41f14838-d639-4ce9-b75b-729e431f67b6"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-05T16:15:02Z",
#     "length": 25916,
#     "billableLength": null,
#     "workItemId": 80836,
#     "comment": "Feature 80836: Login refactoring",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:36:00.3590643",
#     "editedTimestamp": "2023-12-12T15:36:00.3590643",
#     "activityType": {
#       "color": "46aee8",
#       "name": "Feature Development",
#       "id": "9cd0cb39-180d-4b19-9265-83f9753ff76c"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "818c9a83-756b-4b31-8f42-1e3b6dfdf064"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-05T15:02:33Z",
#     "length": 800,
#     "billableLength": null,
#     "workItemId": null,
#     "comment": "Daily",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:36:00.9901512",
#     "editedTimestamp": "2023-12-12T15:36:00.9901512",
#     "activityType": {
#       "color": "ff6600",
#       "name": "People Centric Activities",
#       "id": "ebccdf5e-93ce-4c94-8c31-c4d57712a28b"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "5d727bc8-6773-43a4-8d6c-7f709e6d47ec"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-04T22:00:21Z",
#     "length": 4626,
#     "billableLength": null,
#     "workItemId": 144908,
#     "comment": "Technical Debt 144908: WebApp - Add eslint rule for focus tests .only",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:36:01.5110746",
#     "editedTimestamp": "2023-12-12T15:36:01.5110746",
#     "activityType": {
#       "color": "cc293d",
#       "name": "Bug Fixing",
#       "id": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "d71e8396-f1b4-4b0a-97f5-e8fc6f500f3a"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-04T20:33:19Z",
#     "length": 5229,
#     "billableLength": null,
#     "workItemId": 118384,
#     "comment": "Feature 118384: Horizon: Automatically login",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:36:02.1690999",
#     "editedTimestamp": "2023-12-12T15:36:02.1690999",
#     "activityType": {
#       "color": "46aee8",
#       "name": "Feature Development",
#       "id": "9cd0cb39-180d-4b19-9265-83f9753ff76c"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "ba773117-72bb-422b-82b7-c916ff453d9c"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-04T18:45:47Z",
#     "length": 6422,
#     "billableLength": null,
#     "workItemId": null,
#     "comment": "Carrier path",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:36:02.818371",
#     "editedTimestamp": "2023-12-12T15:36:02.818371",
#     "activityType": {
#       "color": "ff6600",
#       "name": "People Centric Activities",
#       "id": "ebccdf5e-93ce-4c94-8c31-c4d57712a28b"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "8cd74808-4ed3-421a-9d75-9ec9d6ee0ab3"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-04T15:30:09Z",
#     "length": 11734,
#     "billableLength": null,
#     "workItemId": 144908,
#     "comment": "Technical Debt 144908: WebApp - Add eslint rule for focus tests .only",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:36:03.3517133",
#     "editedTimestamp": "2023-12-12T15:36:03.3517133",
#     "activityType": {
#       "color": "cc293d",
#       "name": "Bug Fixing",
#       "id": "140dc2a9-03a0-4431-9f6b-0120f2c1b82f"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "8636f98c-e7a1-4564-91a2-43774e634c12"
#   }
# }
# {
#   "data": {
#     "timestamp": "2023-12-04T15:00:44Z",
#     "length": 944,
#     "billableLength": null,
#     "workItemId": null,
#     "comment": "Daily",
#     "user": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "addedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "editedByUser": {
#       "uniqueName": "cnoll@GENETEC.COM",
#       "displayName": null,
#       "vstsId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "vstsCollectionId2": "b0010469-3e04-6f0f-860c-9ba717df47db",
#       "email": "cnoll@GENETEC.COM",
#       "name": "Corantin Noll",
#       "id": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a"
#     },
#     "createdTimestamp": "2023-12-12T15:36:03.8532204",
#     "editedTimestamp": "2023-12-12T15:36:03.8532204",
#     "activityType": {
#       "color": "ff6600",
#       "name": "People Centric Activities",
#       "id": "ebccdf5e-93ce-4c94-8c31-c4d57712a28b"
#     },
#     "flags": {
#       "isTracked": false,
#       "isManuallyEntered": true,
#       "isChanged": false,
#       "isTrackedExtended": false,
#       "isImported": false,
#       "isFromApi": true,
#       "isBillable": false
#     },
#     "isCanEdit": null,
#     "isCanDelete": null,
#     "id": "61774ef0-995e-4a67-b103-f72708371fb7"
#   }
# }
# Succeeded

# %%
# Print TFS entries
print("TFS entries: " + str(len(tfsEntries)) + " entries")
if(tfsEntries.__len__() > 0):
  uniqueEntries = []
  for entry in tfsEntries:
    existingEntry = None
    for e in uniqueEntries:
      if e['workItemId'] == entry['workItemId']:
        existingEntry = e
        break
    if not existingEntry:
      uniqueEntries.append(entry)
    else:
      existingEntry['length'] += entry['length']
      existingEntry['lengthFriendly'] = "{:0>8}".format(str(timedelta(seconds=existingEntry['length'])))
  print("TFS entries: ")
  print(json.dumps(uniqueEntries, indent=2))
# Out:
# TFS entries: 7 entries
# TFS entries:
# [
#   {
#     "timeStamp": "2023-12-08T21:33:48+00:00",
#     "length": 5613,
#     "lengthFriendly": "01:33:33",
#     "comment": "SwatTask 3427611: [Syracuse City School District] Web app Role gives warning \" failed to start agent\" if add failover server",
#     "workItemId": 3427611,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "d0ae0b59-b071-409b-80f9-c9c2626e08a1",
#     "activityFriendly": "Customer issues"
#   },
#   {
#     "timeStamp": "2023-12-08T15:35:09+00:00",
#     "length": 26960,
#     "lengthFriendly": "07:29:20",
#     "comment": "User Story 3676090: Replace Mobius by NYPD logo",
#     "workItemId": 3676090,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "9cd0cb39-180d-4b19-9265-83f9753ff76c",
#     "activityFriendly": "Feature Development"
#   },
#   {
#     "timeStamp": "2023-12-05T15:15:53+00:00",
#     "length": 3543,
#     "lengthFriendly": "00:59:03",
#     "comment": "EPM Feature 3674768: NYPD - Remove Genetec Logo",
#     "workItemId": 3674768,
#     "userId": "c4da23b7-8578-4f8b-994a-a1953d6b5f6a",
#     "activityTypeId": "9cd0cb39-180d-4b19-9265-83f9753ff76c",
#     "activityFriendly": "Feature Development"
#   }
# ]
